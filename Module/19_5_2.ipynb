# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import pandas as pd
import tensorflow as tf
from google.colab import drive

# Import our input dataset
drive.mount('/content/gdrive')
diabetes_df = pd.read_csv('gdrive/My Drive/diabetes.csv')
diabetes_df.head()
# Out:
# Mounted at /content/gdrive
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# Remove diabetes outcome target from features data
y = diabetes_df.Outcome
X = diabetes_df.drop(columns="Outcome")

# Split training/test datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y)

# %%
# Preprocess numerical data for neural network

# Create a StandardScaler instance
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the logistic regression model
log_classifier = LogisticRegression(solver="lbfgs",max_iter=200)

# Train the model
log_classifier.fit(X_train,y_train)

# Evaluate the model
y_pred = log_classifier.predict(X_test)
print(f" Logistic regression model accuracy: {accuracy_score(y_test,y_pred):.3f}")
# Out:
#  Logistic regression model accuracy: 0.729

# %%
# Define the basic neural network model
nn_model = tf.keras.models.Sequential()
nn_model.add(tf.keras.layers.Dense(units=16, activation="relu", input_dim=8))
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Compile the Sequential model together and customize metrics
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Train the model
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=50)

# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Epoch 1/50
# 18/18 [==============================] - 1s 1ms/step - loss: 0.6867 - accuracy: 0.6302
# Epoch 2/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.6588 - accuracy: 0.6493
# Epoch 3/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.6342 - accuracy: 0.6667
# Epoch 4/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.6124 - accuracy: 0.6806
# Epoch 5/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5938 - accuracy: 0.6997
# Epoch 6/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5765 - accuracy: 0.6979
# Epoch 7/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5615 - accuracy: 0.7153
# Epoch 8/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5475 - accuracy: 0.7257
# Epoch 9/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5358 - accuracy: 0.7413
# Epoch 10/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5246 - accuracy: 0.7500
# Epoch 11/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5154 - accuracy: 0.7535
# Epoch 12/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5076 - accuracy: 0.7639
# Epoch 13/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5001 - accuracy: 0.7708
# Epoch 14/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4945 - accuracy: 0.7743
# Epoch 15/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4894 - accuracy: 0.7812
# Epoch 16/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4840 - accuracy: 0.7778
# Epoch 17/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4804 - accuracy: 0.7795
# Epoch 18/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4765 - accuracy: 0.7795
# Epoch 19/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4734 - accuracy: 0.7812
# Epoch 20/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4707 - accuracy: 0.7865
# Epoch 21/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4681 - accuracy: 0.7899
# Epoch 22/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4660 - accuracy: 0.7882
# Epoch 23/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4642 - accuracy: 0.7969
# Epoch 24/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4624 - accuracy: 0.7969
# Epoch 25/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4609 - accuracy: 0.8003
# Epoch 26/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4595 - accuracy: 0.8003
# Epoch 27/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4583 - accuracy: 0.7986
# Epoch 28/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4573 - accuracy: 0.7969
# Epoch 29/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4561 - accuracy: 0.7969
# Epoch 30/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4552 - accuracy: 0.7969
# Epoch 31/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4545 - accuracy: 0.7969
# Epoch 32/50
# 18/18 [==============================] - 0s 6ms/step - loss: 0.4536 - accuracy: 0.7969
# Epoch 33/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4531 - accuracy: 0.7969
# Epoch 34/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4523 - accuracy: 0.7951
# Epoch 35/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4515 - accuracy: 0.7986
# Epoch 36/50
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4513 - accuracy: 0.7969
# Epoch 37/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4502 - accuracy: 0.7969
# Epoch 38/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4500 - accuracy: 0.7951
# Epoch 39/50
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4490 - accuracy: 0.7969
# Epoch 40/50
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4488 - accuracy: 0.7969
# Epoch 41/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4480 - accuracy: 0.7969
# Epoch 42/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4476 - accuracy: 0.7934
# Epoch 43/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4467 - accuracy: 0.7934
# Epoch 44/50
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4462 - accuracy: 0.7934
# Epoch 45/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4462 - accuracy: 0.7934
# Epoch 46/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4453 - accuracy: 0.7899
# Epoch 47/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4448 - accuracy: 0.7951
# Epoch 48/50
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4444 - accuracy: 0.7934
# Epoch 49/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4442 - accuracy: 0.7951
# Epoch 50/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4434 - accuracy: 0.7934
# 6/6 - 0s - loss: 0.4751 - accuracy: 0.7500 - 234ms/epoch - 39ms/step
# Loss: 0.47511959075927734, Accuracy: 0.75
